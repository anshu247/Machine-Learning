# %% [markdown]
# # TRAFFIC SIGN CLASSIFICATION

# %% [markdown]
# Traffic sign classification is important for self driving cars. In this dataset there are 43 different classes. In this project, we will train Deep Convolution Neural Network (CNN)to classify Traffic Signals .Images are of 32*32 pixels and Coloured Image consist of 3 RGB Channels for Red,Green,Blue

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pickle
import random
import tensorflow as tf
import seaborn as sns

# %% [markdown]
# #### Data is divided to 60%,20%,20% segment for training,validation,and testing.
# - `TRAINING SET:` USED FOR GRADIENT CALCULATION AND WEIGHT UPDATE
# - `VALIDATION SET:`USED FOR CROSS-VALIDATION TO OVERCOME FITTING
# - `TESTING SET:` USED FOR TESTING CNN

# %%
# mode rb denotes read-binary
with open("train.p", mode='rb') as training_data:
    train = pickle.load(training_data)
with open("valid.p", mode='rb') as validation_data:
    valid = pickle.load(validation_data)
with open("test.p", mode='rb') as testing_data:
    test = pickle.load(testing_data)

# %%
X_train, y_train = train['features'], train['labels']
X_validation, y_validation = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# %%
print("X_train data shape: ",X_train.shape,y_train.shape)
# Out:
# X_train data shape:  (34799, 32, 32, 3) (34799,)

# %%
X_test.shape, y_test.shape
# Out:
# ((12630, 32, 32, 3), (12630,))

# %%
X_validation.shape, y_validation.shape
# Out:
# ((4410, 32, 32, 3), (4410,))

# %% [markdown]
# ## PERFROM IMAGES VISUALIZATION

# %%
i = np.random.randint(1, len(X_train))
plt.imshow(X_train[i])


y_train[i]
# Out:
# 12

# %%
# Let's view more images in a grid format
# Define the dimensions of the plot grid 
W_grid = 5
L_grid = 5

# fig, axes = plt.subplots(L_grid, W_grid)
# subplot return the figure object and axes object
# we can use the axes object to plot specific figures at various locations

fig, axes = plt.subplots(L_grid, W_grid, figsize = (10,10))

axes = axes.ravel() # flaten the 15 x 15 matrix into 225 array

n_training = len(X_train) # get the length of the training dataset

# Select a random number from 0 to n_training
for i in np.arange(0, W_grid * L_grid): # create evenly spaces variables 

    # Select a random number
    index = np.random.randint(0, n_training)
    # read and display an image with the selected index    
    axes[i].imshow( X_train[index])
    axes[i].set_title(y_train[index], fontsize = 15)
    axes[i].axis('off')

plt.subplots_adjust(hspace=0.4)

# %% [markdown]
# # CONVERT IMAGES TO GRAYSCALE AND PERFORM NORMALIZATION

# %%
from sklearn.utils import shuffle
X_train, y_train = shuffle(X_train, y_train)

# %% [markdown]
# We are doing shuffle because we don't want that our network to learn the order of the data.

# %% [markdown]
# ### Convert to grey Scale

# %%
X_train_gray = np.sum(X_train/3, axis = 3, keepdims = True)
X_test_gray = np.sum(X_test/3, axis = 3, keepdims = True)
X_validation_gray = np.sum(X_validation/3, axis = 3, keepdims = True)

# %% [markdown]
# ### Normalize

# %%
X_train_gray_norm = (X_train_gray - 128)/128
X_test_gray_norm = (X_test_gray - 128)/128
X_validation_gray_norm = (X_validation_gray - 128)/128

# %%
i = random.randint(1, len(X_train_gray))
plt.imshow(X_train_gray[i].squeeze(), cmap = 'gray')
plt.figure()
plt.imshow(X_train[i])
plt.figure()
plt.imshow(X_train_gray_norm[i].squeeze(), cmap = 'gray')

# %% [markdown]
# ## BUILD DEEP CONVOLUTIONAL NEURAL NETWORK MODEL

# %%
from tensorflow.keras import datasets, layers, models

CNN = models.Sequential()

CNN.add(layers.Conv2D(6, (5,5), activation = 'relu', input_shape = (32,32,1)))
CNN.add(layers.AveragePooling2D())

#CNN.add(layers.Dropout(0.2))

CNN.add(layers.Conv2D(16, (5,5), activation = 'relu'))
CNN.add(layers.AveragePooling2D())

CNN.add(layers.Flatten())

CNN.add(layers.Dense(120, activation = 'relu'))

CNN.add(layers.Dense(84, activation = 'relu'))

CNN.add(layers.Dense(43, activation = 'softmax'))
CNN.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 6)         156
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 400)               0
# _________________________________________________________________
# dense (Dense)                (None, 120)               48120
# _________________________________________________________________
# dense_1 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_2 (Dense)              (None, 43)                3655
# =================================================================
# Total params: 64,511
# Trainable params: 64,511
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## COMPILE AND TRAIN DEEP CNN MODE

# %%
CNN.compile(optimizer = 'Adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

# %%
history = CNN.fit(X_train_gray_norm,
                 y_train, 
                 batch_size = 500,
                 nb_epoch = 50,
                 verbose = 1,
                 validation_data = (X_validation_gray_norm, y_validation))
# Out:
# WARNING:tensorflow:The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Train on 34799 samples, validate on 4410 samples
# Epoch 1/50
# 34799/34799 [==============================] - 28s 808us/sample - loss: 3.2622 - accuracy: 0.1547 - val_loss: 2.9560 - val_accuracy: 0.2660
# Epoch 2/50
# 34799/34799 [==============================] - 24s 682us/sample - loss: 1.8405 - accuracy: 0.4959 - val_loss: 1.4869 - val_accuracy: 0.5662
# Epoch 3/50
# 34799/34799 [==============================] - 24s 686us/sample - loss: 0.9662 - accuracy: 0.7180 - val_loss: 1.0257 - val_accuracy: 0.7023
# Epoch 4/50
# 34799/34799 [==============================] - 25s 717us/sample - loss: 0.6735 - accuracy: 0.8064 - val_loss: 0.8070 - val_accuracy: 0.7608
# Epoch 5/50
# 34799/34799 [==============================] - 26s 733us/sample - loss: 0.5142 - accuracy: 0.8590 - val_loss: 0.7234 - val_accuracy: 0.7912
# Epoch 6/50
# 34799/34799 [==============================] - 25s 730us/sample - loss: 0.4238 - accuracy: 0.8872 - val_loss: 0.6731 - val_accuracy: 0.8068
# Epoch 7/50
# 34799/34799 [==============================] - 25s 724us/sample - loss: 0.3606 - accuracy: 0.9043 - val_loss: 0.6517 - val_accuracy: 0.8172
# Epoch 8/50
# 34799/34799 [==============================] - 24s 697us/sample - loss: 0.3089 - accuracy: 0.9193 - val_loss: 0.6599 - val_accuracy: 0.8261
# Epoch 9/50
# 34799/34799 [==============================] - 24s 695us/sample - loss: 0.2770 - accuracy: 0.9299 - val_loss: 0.6381 - val_accuracy: 0.8268
# Epoch 10/50
# 34799/34799 [==============================] - 24s 691us/sample - loss: 0.2422 - accuracy: 0.9408 - val_loss: 0.5883 - val_accuracy: 0.8424
# Epoch 11/50
# 34799/34799 [==============================] - 24s 692us/sample - loss: 0.2161 - accuracy: 0.9466 - val_loss: 0.5954 - val_accuracy: 0.8431
# Epoch 12/50
# 34799/34799 [==============================] - 24s 694us/sample - loss: 0.2022 - accuracy: 0.9501 - val_loss: 0.6019 - val_accuracy: 0.8465
# Epoch 13/50
# 34799/34799 [==============================] - 24s 698us/sample - loss: 0.1813 - accuracy: 0.9561 - val_loss: 0.6376 - val_accuracy: 0.8376
# Epoch 14/50
# 34799/34799 [==============================] - 25s 712us/sample - loss: 0.1667 - accuracy: 0.9593 - val_loss: 0.5781 - val_accuracy: 0.8512
# Epoch 15/50
# 34799/34799 [==============================] - 25s 728us/sample - loss: 0.1544 - accuracy: 0.9622 - val_loss: 0.5767 - val_accuracy: 0.8599
# Epoch 16/50
# 34799/34799 [==============================] - 25s 711us/sample - loss: 0.1397 - accuracy: 0.9666 - val_loss: 0.6677 - val_accuracy: 0.8449
# Epoch 17/50
# 34799/34799 [==============================] - 25s 722us/sample - loss: 0.1323 - accuracy: 0.9681 - val_loss: 0.5764 - val_accuracy: 0.8633
# Epoch 18/50
# 34799/34799 [==============================] - 25s 727us/sample - loss: 0.1184 - accuracy: 0.9717 - val_loss: 0.6196 - val_accuracy: 0.8553
# Epoch 19/50
# 34799/34799 [==============================] - 25s 722us/sample - loss: 0.1139 - accuracy: 0.9728 - val_loss: 0.6155 - val_accuracy: 0.8442
# Epoch 20/50
# 34799/34799 [==============================] - 22s 641us/sample - loss: 0.0996 - accuracy: 0.9773 - val_loss: 0.6478 - val_accuracy: 0.8519
# Epoch 21/50
# 34799/34799 [==============================] - 22s 618us/sample - loss: 0.0935 - accuracy: 0.9786 - val_loss: 0.6629 - val_accuracy: 0.8474
# Epoch 22/50
# 34799/34799 [==============================] - 23s 656us/sample - loss: 0.0871 - accuracy: 0.9795 - val_loss: 0.6482 - val_accuracy: 0.8503
# Epoch 23/50
# 34799/34799 [==============================] - 24s 683us/sample - loss: 0.0832 - accuracy: 0.9810 - val_loss: 0.6649 - val_accuracy: 0.8549
# Epoch 24/50
# 34799/34799 [==============================] - 23s 653us/sample - loss: 0.0727 - accuracy: 0.9838 - val_loss: 0.6771 - val_accuracy: 0.8544
# Epoch 25/50
# 34799/34799 [==============================] - 23s 660us/sample - loss: 0.0712 - accuracy: 0.9831 - val_loss: 0.6744 - val_accuracy: 0.8533
# Epoch 26/50
# 34799/34799 [==============================] - 25s 707us/sample - loss: 0.0648 - accuracy: 0.9854 - val_loss: 0.6438 - val_accuracy: 0.8603
# Epoch 27/50
# 34799/34799 [==============================] - 25s 705us/sample - loss: 0.0606 - accuracy: 0.9855 - val_loss: 0.6831 - val_accuracy: 0.8512
# Epoch 28/50
# 34799/34799 [==============================] - 25s 721us/sample - loss: 0.0535 - accuracy: 0.9876 - val_loss: 0.6739 - val_accuracy: 0.8560
# Epoch 29/50
# 34799/34799 [==============================] - 24s 701us/sample - loss: 0.0518 - accuracy: 0.9884 - val_loss: 0.7258 - val_accuracy: 0.8512
# Epoch 30/50
# 34799/34799 [==============================] - 24s 693us/sample - loss: 0.0500 - accuracy: 0.9882 - val_loss: 0.6736 - val_accuracy: 0.8637
# Epoch 31/50
# 34799/34799 [==============================] - 24s 704us/sample - loss: 0.0491 - accuracy: 0.9875 - val_loss: 0.6906 - val_accuracy: 0.8642
# Epoch 32/50
# 34799/34799 [==============================] - 25s 709us/sample - loss: 0.0429 - accuracy: 0.9898 - val_loss: 0.7149 - val_accuracy: 0.8578
# Epoch 33/50
# 34799/34799 [==============================] - 25s 706us/sample - loss: 0.0420 - accuracy: 0.9897 - val_loss: 0.6883 - val_accuracy: 0.8599
# Epoch 34/50
# 34799/34799 [==============================] - 24s 693us/sample - loss: 0.0357 - accuracy: 0.9918 - val_loss: 0.6794 - val_accuracy: 0.8605
# Epoch 35/50
# 34799/34799 [==============================] - 25s 721us/sample - loss: 0.0332 - accuracy: 0.9924 - val_loss: 0.7011 - val_accuracy: 0.8596
# Epoch 36/50
# 34799/34799 [==============================] - 27s 762us/sample - loss: 0.0321 - accuracy: 0.9924 - val_loss: 0.7493 - val_accuracy: 0.8603
# Epoch 37/50
# 34799/34799 [==============================] - 26s 754us/sample - loss: 0.0304 - accuracy: 0.9929 - val_loss: 0.7153 - val_accuracy: 0.8703
# Epoch 38/50
# 34799/34799 [==============================] - 26s 756us/sample - loss: 0.0278 - accuracy: 0.9935 - val_loss: 0.7294 - val_accuracy: 0.8671
# Epoch 39/50
# 34799/34799 [==============================] - 27s 774us/sample - loss: 0.0306 - accuracy: 0.9922 - val_loss: 0.7114 - val_accuracy: 0.8753
# Epoch 40/50
# 34799/34799 [==============================] - 26s 743us/sample - loss: 0.0255 - accuracy: 0.9940 - val_loss: 0.7458 - val_accuracy: 0.8628
# Epoch 41/50
# 34799/34799 [==============================] - 24s 690us/sample - loss: 0.0231 - accuracy: 0.9944 - val_loss: 0.7692 - val_accuracy: 0.8612
# Epoch 42/50
# 34799/34799 [==============================] - 24s 685us/sample - loss: 0.0221 - accuracy: 0.9946 - val_loss: 0.7143 - val_accuracy: 0.8710
# Epoch 43/50
# 34799/34799 [==============================] - 27s 774us/sample - loss: 0.0251 - accuracy: 0.9934 - val_loss: 0.7335 - val_accuracy: 0.8701
# Epoch 44/50
# 34799/34799 [==============================] - 26s 737us/sample - loss: 0.0169 - accuracy: 0.9963 - val_loss: 0.7686 - val_accuracy: 0.8703
# Epoch 45/50
# 34799/34799 [==============================] - 23s 659us/sample - loss: 0.0272 - accuracy: 0.9922 - val_loss: 0.7244 - val_accuracy: 0.8714
# Epoch 46/50
# 34799/34799 [==============================] - 24s 680us/sample - loss: 0.0175 - accuracy: 0.9958 - val_loss: 0.7640 - val_accuracy: 0.8726
# Epoch 47/50
# 34799/34799 [==============================] - 24s 680us/sample - loss: 0.0154 - accuracy: 0.9962 - val_loss: 0.7836 - val_accuracy: 0.8710
# Epoch 48/50
# 34799/34799 [==============================] - 25s 714us/sample - loss: 0.0154 - accuracy: 0.9961 - val_loss: 0.7658 - val_accuracy: 0.8732
# Epoch 49/50
# 34799/34799 [==============================] - 25s 704us/sample - loss: 0.0127 - accuracy: 0.9973 - val_loss: 0.7414 - val_accuracy: 0.8819
# Epoch 50/50
# 34799/34799 [==============================] - 24s 678us/sample - loss: 0.0109 - accuracy: 0.9976 - val_loss: 0.7620 - val_accuracy: 0.8723

# %% [markdown]
# ## ASSESS TRAINED CNN MODEL PERFORMANCE

# %%
score = CNN.evaluate(X_test_gray_norm, y_test)
print('Test Accuracy: {}'.format(score[1]))
# Out:
# 12630/12630 [==============================] - 3s 232us/sample - loss: 1.3025 - accuracy: 0.8672
# Test Accuracy: 0.8672208786010742

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
epochs = range(len(accuracy))

plt.plot(epochs, accuracy, 'bo', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

# %%
plt.plot(epochs, loss, 'ro', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and Validation loss')
plt.legend()

# %%
predicted_classes = CNN.predict_classes(X_test_gray_norm)
y_true = y_test

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_true, predicted_classes)
plt.figure(figsize = (25, 25))
sns.heatmap(cm, annot = True)

# %% [markdown]
# The Heatmap diagonal shows that correctly classified images and other then that is predicted falsely

# %%
L = 5
W = 5

fig, axes = plt.subplots(L, W, figsize = (12, 12))
axes = axes.ravel()

for i in np.arange(0, L*W):
    axes[i].imshow(X_test[i])
    axes[i].set_title('Prediction = {}\n True = {}'.format(predicted_classes[i], y_true[i]))
    axes[i].axis('off')

plt.subplots_adjust(wspace = 1)

# %% [markdown]
# # Thank You
