# %% [markdown]
# # CONVOLUTIONAL NEURAL NETWORK (CNN'S)

# %% [markdown]
#   A Convolutional Neural Network (ConvNet/CNN) is a Deep Learning algorithm which can take in an input image, assign importance (learnable weights and biases) to various aspects/objects in the image and be able to differentiate one from the other.![1_1VJDP6qDY9-ExTuQVEOlVg%5B1%5D.gif](attachment:1_1VJDP6qDY9-ExTuQVEOlVg%5B1%5D.gif)

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img_=cv2.imread('cat.jfif')

# %%
plt.imshow(img_)

# %% [markdown]
# As the Image is 3D so we need 3D filter. But in this case to make things simple we are converting BGR image to gray image which is 2D image so that we can apply 2D filter.

# %%
grayImage = cv2.cvtColor(img_, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(grayImage,cmap="gray")

# %%
grayImage.shape
# Out:
# (224, 225)

# %% [markdown]
# ###### CONVELOTION LAYER:
#     A convolution is the simple application of a filter to an input that results in an activation. Repeated application of the same filter to an input results in a map of activations called a feature map, indicating the locations and strength of a detected feature in an input, such as an image.

# %% [markdown]
#
#  The output image we contain (W-F+1)*(H-F+1)
# dimensions .
#
#
# W,H is width,height of image to be labeled and F is shape of filter

# %%
def Convelotion(img,img_filter):
    W=img.shape[0]
    H=img.shape[1]
    F=img_filter.shape[0]
    new_img=np.zeros((W-F+1,H-F+1))
    
    for row in range(W-F+1):
        for col in range(H-F+1):
            for i in range(F):
                for j in range(F):
                    new_img[row][col]+= img[row+i][col+j]*img_filter[i][j]
                if new_img[row][col]>255:
                    new_img[row][col]=255
                elif new_img[row][col]<0:
                    new_img[row][col]=0
                    
    return new_img

# %%
blur_filter=np.ones((3,3))/9.0

# %%
op1=Convelotion(grayImage,blur_filter)

# %%
plt.imshow(grayImage,cmap='gray')

# %%
plt.imshow(op1,cmap='gray')

# %%
edge_filter=np.array([[1,0,-1],[1,0,-1],[1,0,-1]])

# %%
op1=Convelotion(grayImage,edge_filter)

# %%
plt.imshow(op1,cmap='gray')

# %% [markdown]
# ## THANK YOU
